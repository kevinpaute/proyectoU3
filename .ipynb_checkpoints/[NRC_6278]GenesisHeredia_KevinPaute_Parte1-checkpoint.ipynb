# %% [markdown]
# <center><h1>Laboratorio 1 CNN - Inteligencia Artificial</h1></center>
#
# Nombres:
#
# - Genesis Heredia
# - Kevin Paute Sánchez
#
# Fecha: 13/08/2022

# %% [markdown]
# # Importar librerías

# %%
#Se realiza la importación de la libreria cv2
import cv2
#Se realiza la importación de la libreria numpy
import numpy as np
#Se realiza la importación de la libreria os
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
#Se realiza la importación de la libreria pandas
import pandas as pd
#Se realiza la importación de la libreria plt
import matplotlib.pyplot as plt
#Se realiza la importación de la libreria seaborn
import seaborn as sn
#Se realiza la importación de la libreria keras
from keras.preprocessing.image import ImageDataGenerator
#Se importa shutil
import shutil
#Se importa glob
import glob
#Se importa tensorflow
from tensorflow.keras.utils import img_to_array, array_to_img, img_to_array, load_img
#Se importa Image de PIL
from  PIL  import Image
#Se importa remove de rembg
from rembg import remove
#Se importa MinMaxScaler de sklearn
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Cargar dataset

# %%
#Se cargan las imagenes del dataset colocando la ruta de la carpeta general
ruta_imagenes = "dataset_imagenes"
#Función que permite listar las carpetas que contiene 
clases = os.listdir(ruta_imagenes)
#Función que permite clasificar los nombres de cada carpeta
clases.sort()
#Imprimir los nombres de las carpetas
print(clases)
# Out:
# ['ArroboMercy', 'CevallosJoan', 'GenesisHeredia', 'PauteKevin', 'RivasSelena']

# %% [markdown]
# # Preprocesamiento de imágenes

# %%
'''
    Ciclo for para copiar las imágenes y realizar data aumented
'''
for n_clase in clases:
    #Selecciona la ruta de las imagenes y las une con el nombre de la calse
    cur_path = ruta_imagenes + "/" + n_clase
    elements = os.listdir(cur_path)
    
    for element in elements:
        #Muestra el bucle de las imagenes que está aplicandose data augmented
        print("Copiando imagen - {} en dataset_imagenes_augmented/{}".format(element, n_clase))
        # lee el origen de la ruta
        src = os.path.join(ruta_imagenes + "/" + n_clase, element) 
        # Guarda las imagenes en la carpeta especificada
        dst = os.path.join("dataset_imagenes_augmented/" + n_clase, element) 
        shutil.copy(src, dst)
# Out:
# Copiando imagen - L00385770_1.png en dataset_imagenes_augmented/ArroboMercy
# Copiando imagen - L00385770_2.png en dataset_imagenes_augmented/ArroboMercy
# Copiando imagen - L00385770_3.png en dataset_imagenes_augmented/ArroboMercy
# Copiando imagen - L00376416_1.jpg en dataset_imagenes_augmented/CevallosJoan
# Copiando imagen - L00376416_2.jpg en dataset_imagenes_augmented/CevallosJoan
# Copiando imagen - L00376416_3.jpg en dataset_imagenes_augmented/CevallosJoan
# Copiando imagen - L00392991_1.png en dataset_imagenes_augmented/GenesisHeredia
# Copiando imagen - L00392991_2.png en dataset_imagenes_augmented/GenesisHeredia
# Copiando imagen - L00392991_3.png en dataset_imagenes_augmented/GenesisHeredia
# Copiando imagen - L00080134_1.jpg en dataset_imagenes_augmented/PauteKevin
# Copiando imagen - L00080134_2.jpg en dataset_imagenes_augmented/PauteKevin
# Copiando imagen - L00080134_3.jpg en dataset_imagenes_augmented/PauteKevin
# Copiando imagen - L00376689_1.jpg en dataset_imagenes_augmented/RivasSelena
# Copiando imagen - L00376689_2.jpg en dataset_imagenes_augmented/RivasSelena
# Copiando imagen - L00376689_3.jpg en dataset_imagenes_augmented/RivasSelena

# %% [markdown]
# ## Data augmentation

# %%
datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.4,
        horizontal_flip=True,
        fill_mode='nearest')

# %% [markdown]
# ### Clase CevallosJoan

# %%
os.chdir(r"C:\Users\usuar\Documents\Laboratorio1U3\laboratorioCNN\dataset_imagenes_augmented\CevallosJoan")
for ruta in os.listdir():
    img = load_img(f"{ruta}")
    x = img_to_array(img) 
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'CevallosJoan', 
            save_format='jpg'):
        i += 1
        if i == 9:      
            break

# %% [markdown]
# ### Clase GenesisHeredia

# %%
os.chdir(r"C:\Users\usuar\Documents\Laboratorio1U3\laboratorioCNN\dataset_imagenes_augmented\GenesisHeredia")
for ruta in os.listdir():
    img = load_img(f"{ruta}")
    x = img_to_array(img) 
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'GenesisHeredia', 
            save_format='jpg'):
        i += 1
        if i == 9:      
            break

# %% [markdown]
# ### Clase ArroboMercy

# %%
os.chdir(r"C:\Users\usuar\Documents\Laboratorio1U3\laboratorioCNN\dataset_imagenes_augmented\ArroboMercy")
for ruta in os.listdir():
    img = load_img(f"{ruta}")
    x = img_to_array(img) 
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'ArroboMercy', 
            save_format='jpg'):
        i += 1
        if i == 9:      
            break

# %% [markdown]
# ### Clase PauteKevin

# %%
os.chdir(r"C:\Users\usuar\Documents\Laboratorio1U3\laboratorioCNN\dataset_imagenes_augmented\PauteKevin")
for ruta in os.listdir():
    img = load_img(f"{ruta}")
    x = img_to_array(img) 
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'PauteKevin', 
            save_format='jpg'):
        i += 1
        if i == 9:      
            break

# %% [markdown]
# ### Clase RivasSelena

# %%
os.chdir(r"C:\Users\usuar\Documents\Laboratorio1U3\laboratorioCNN\dataset_imagenes_augmented\RivasSelena")
for ruta in os.listdir():
    img = load_img(f"{ruta}")
    x = img_to_array(img) 
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'RivasSelena', 
            save_format='jpg'):
        i += 1
        if i == 9:      
            break

# %% [markdown]
# ## Filtro NLM para eliminación de ruido de imágenes

# %%
#Se cargan las imagenes del dataset colocando la ruta de la carpeta general
os.chdir(r"C:\Users\usuar\Documents\Laboratorio1U3\laboratorioCNN")
ruta_imagenes = "dataset_imagenes_augmented"
#Función que permite listar las carpetas que contiene 
nombre_clases = os.listdir(ruta_imagenes)
#Función que permite clasificar los nombres de cada carpeta
nombre_clases.sort()
#Imprimir los nombres de las carpetas
print(nombre_clases)
# Out:
# ['ArroboMercy', 'CevallosJoan', 'GenesisHeredia', 'PauteKevin', 'RivasSelena']

# %%
for n_clase in nombre_clases:
    cur_path = ruta_imagenes + "/" + n_clase
    cur_label = n_clase
    i = 1

    for archivo in glob.glob(cur_path + "/*"):
        print("Procesando Imagen - {} en {}".format(i, cur_label))
        # Lee la rute de las imagenes
        image = cv2.imread(archivo)
        # Cambia el ruido de las imagenes
        dst = cv2.fastNlMeansDenoisingColored(image,None,10,10,7,21)
        b,g,r = cv2.split(dst)
        rgb_dst = cv2.merge([r,g,b])
        
        save_path = 'dataset_imagenes_denoised/'+ cur_label
        cv2.imwrite(os.path.join(save_path , cur_label + '_' + str(i) + '.jpg'),
                    cv2.cvtColor(rgb_dst,cv2.COLOR_RGB2BGR))
        

        # Muestra la actualización de bucle
        i += 1
# Out:
# Procesando Imagen - 1 en ArroboMercy
# Procesando Imagen - 2 en ArroboMercy
# Procesando Imagen - 3 en ArroboMercy
# Procesando Imagen - 4 en ArroboMercy
# Procesando Imagen - 5 en ArroboMercy
# Procesando Imagen - 6 en ArroboMercy
# Procesando Imagen - 7 en ArroboMercy
# Procesando Imagen - 8 en ArroboMercy
# Procesando Imagen - 9 en ArroboMercy
# Procesando Imagen - 10 en ArroboMercy
# Procesando Imagen - 11 en ArroboMercy
# Procesando Imagen - 12 en ArroboMercy
# Procesando Imagen - 13 en ArroboMercy
# Procesando Imagen - 14 en ArroboMercy
# Procesando Imagen - 15 en ArroboMercy
# Procesando Imagen - 16 en ArroboMercy
# Procesando Imagen - 17 en ArroboMercy
# Procesando Imagen - 18 en ArroboMercy
# Procesando Imagen - 19 en ArroboMercy
# Procesando Imagen - 20 en ArroboMercy
# Procesando Imagen - 21 en ArroboMercy
# Procesando Imagen - 22 en ArroboMercy
# Procesando Imagen - 23 en ArroboMercy
# Procesando Imagen - 24 en ArroboMercy
# Procesando Imagen - 25 en ArroboMercy
# Procesando Imagen - 26 en ArroboMercy
# Procesando Imagen - 27 en ArroboMercy
# Procesando Imagen - 28 en ArroboMercy
# Procesando Imagen - 29 en ArroboMercy
# Procesando Imagen - 30 en ArroboMercy
# Procesando Imagen - 1 en CevallosJoan
# Procesando Imagen - 2 en CevallosJoan
# Procesando Imagen - 3 en CevallosJoan
# Procesando Imagen - 4 en CevallosJoan
# Procesando Imagen - 5 en CevallosJoan
# Procesando Imagen - 6 en CevallosJoan
# Procesando Imagen - 7 en CevallosJoan
# Procesando Imagen - 8 en CevallosJoan
# Procesando Imagen - 9 en CevallosJoan
# Procesando Imagen - 10 en CevallosJoan
# Procesando Imagen - 11 en CevallosJoan
# Procesando Imagen - 12 en CevallosJoan
# Procesando Imagen - 13 en CevallosJoan
# Procesando Imagen - 14 en CevallosJoan
# Procesando Imagen - 15 en CevallosJoan
# Procesando Imagen - 16 en CevallosJoan
# Procesando Imagen - 17 en CevallosJoan
# Procesando Imagen - 18 en CevallosJoan
# Procesando Imagen - 19 en CevallosJoan
# Procesando Imagen - 20 en CevallosJoan
# Procesando Imagen - 21 en CevallosJoan
# Procesando Imagen - 22 en CevallosJoan
# Procesando Imagen - 23 en CevallosJoan
# Procesando Imagen - 24 en CevallosJoan
# Procesando Imagen - 25 en CevallosJoan
# Procesando Imagen - 26 en CevallosJoan
# Procesando Imagen - 27 en CevallosJoan
# Procesando Imagen - 28 en CevallosJoan
# Procesando Imagen - 29 en CevallosJoan
# Procesando Imagen - 30 en CevallosJoan
# Procesando Imagen - 1 en GenesisHeredia
# Procesando Imagen - 2 en GenesisHeredia
# Procesando Imagen - 3 en GenesisHeredia
# Procesando Imagen - 4 en GenesisHeredia
# Procesando Imagen - 5 en GenesisHeredia
# Procesando Imagen - 6 en GenesisHeredia
# Procesando Imagen - 7 en GenesisHeredia
# Procesando Imagen - 8 en GenesisHeredia
# Procesando Imagen - 9 en GenesisHeredia
# Procesando Imagen - 10 en GenesisHeredia
# Procesando Imagen - 11 en GenesisHeredia
# Procesando Imagen - 12 en GenesisHeredia
# Procesando Imagen - 13 en GenesisHeredia
# Procesando Imagen - 14 en GenesisHeredia
# Procesando Imagen - 15 en GenesisHeredia
# Procesando Imagen - 16 en GenesisHeredia
# Procesando Imagen - 17 en GenesisHeredia
# Procesando Imagen - 18 en GenesisHeredia
# Procesando Imagen - 19 en GenesisHeredia
# Procesando Imagen - 20 en GenesisHeredia
# Procesando Imagen - 21 en GenesisHeredia
# Procesando Imagen - 22 en GenesisHeredia
# Procesando Imagen - 23 en GenesisHeredia
# Procesando Imagen - 24 en GenesisHeredia
# Procesando Imagen - 25 en GenesisHeredia
# Procesando Imagen - 26 en GenesisHeredia
# Procesando Imagen - 27 en GenesisHeredia
# Procesando Imagen - 28 en GenesisHeredia
# Procesando Imagen - 29 en GenesisHeredia
# Procesando Imagen - 30 en GenesisHeredia
# Procesando Imagen - 1 en PauteKevin
# Procesando Imagen - 2 en PauteKevin
# Procesando Imagen - 3 en PauteKevin
# Procesando Imagen - 4 en PauteKevin
# Procesando Imagen - 5 en PauteKevin
# Procesando Imagen - 6 en PauteKevin
# Procesando Imagen - 7 en PauteKevin
# Procesando Imagen - 8 en PauteKevin
# Procesando Imagen - 9 en PauteKevin
# Procesando Imagen - 10 en PauteKevin
# Procesando Imagen - 11 en PauteKevin
# Procesando Imagen - 12 en PauteKevin
# Procesando Imagen - 13 en PauteKevin
# Procesando Imagen - 14 en PauteKevin
# Procesando Imagen - 15 en PauteKevin
# Procesando Imagen - 16 en PauteKevin
# Procesando Imagen - 17 en PauteKevin
# Procesando Imagen - 18 en PauteKevin
# Procesando Imagen - 19 en PauteKevin
# Procesando Imagen - 20 en PauteKevin
# Procesando Imagen - 21 en PauteKevin
# Procesando Imagen - 22 en PauteKevin
# Procesando Imagen - 23 en PauteKevin
# Procesando Imagen - 24 en PauteKevin
# Procesando Imagen - 25 en PauteKevin
# Procesando Imagen - 26 en PauteKevin
# Procesando Imagen - 27 en PauteKevin
# Procesando Imagen - 28 en PauteKevin
# Procesando Imagen - 29 en PauteKevin
# Procesando Imagen - 30 en PauteKevin
# Procesando Imagen - 1 en RivasSelena
# Procesando Imagen - 2 en RivasSelena
# Procesando Imagen - 3 en RivasSelena
# Procesando Imagen - 4 en RivasSelena
# Procesando Imagen - 5 en RivasSelena
# Procesando Imagen - 6 en RivasSelena
# Procesando Imagen - 7 en RivasSelena
# Procesando Imagen - 8 en RivasSelena
# Procesando Imagen - 9 en RivasSelena
# Procesando Imagen - 10 en RivasSelena
# Procesando Imagen - 11 en RivasSelena
# Procesando Imagen - 12 en RivasSelena
# Procesando Imagen - 13 en RivasSelena
# Procesando Imagen - 14 en RivasSelena
# Procesando Imagen - 15 en RivasSelena
# Procesando Imagen - 16 en RivasSelena
# Procesando Imagen - 17 en RivasSelena
# Procesando Imagen - 18 en RivasSelena
# Procesando Imagen - 19 en RivasSelena
# Procesando Imagen - 20 en RivasSelena
# Procesando Imagen - 21 en RivasSelena
# Procesando Imagen - 22 en RivasSelena
# Procesando Imagen - 23 en RivasSelena
# Procesando Imagen - 24 en RivasSelena
# Procesando Imagen - 25 en RivasSelena
# Procesando Imagen - 26 en RivasSelena
# Procesando Imagen - 27 en RivasSelena
# Procesando Imagen - 28 en RivasSelena
# Procesando Imagen - 29 en RivasSelena
# Procesando Imagen - 30 en RivasSelena

# %% [markdown]
# ## Background Removal

# %%
#Se cargan las imagenes del dataset colocando la ruta de la carpeta general
os.chdir(r"C:\Users\usuar\Documents\Laboratorio1U3\laboratorioCNN")
ruta_imagenes = "dataset_imagenes_denoised"
#Función que permite listar las carpetas que contiene 
nombre_clases = os.listdir(ruta_imagenes)
#Función que permite clasificar los nombres de cada carpeta
nombre_clases.sort()
#Imprimir los nombres de las carpetas
print(nombre_clases)
# Out:
# ['ArroboMercy', 'CevallosJoan', 'GenesisHeredia', 'PauteKevin', 'RivasSelena']

# %%
for n_clase in nombre_clases:
    cur_path = ruta_imagenes + "/" + n_clase
    cur_label = n_clase
    i = 1
    
    for archivo in glob.glob(cur_path + "/*"):
        print("Procesando Imagen - {} en {}".format(i, cur_label))
        # Leer la ruta de imagenes
        image = cv2.imread(archivo)
        # Eliminar el fondo de la imagen
        output = remove(image)
        # Guarda las imagenes en la ruta removedBG
        save_path = 'dataset_imagenes_removedBG/'+ cur_label
        cv2.imwrite(os.path.join(save_path , cur_label + '_' + str(i) + '.png'), output)
        

        # Muestra la actualización de bucle
        i += 1
# Out:
# Procesando Imagen - 1 en ArroboMercy
# Procesando Imagen - 2 en ArroboMercy
# Procesando Imagen - 3 en ArroboMercy
# Procesando Imagen - 4 en ArroboMercy
# Procesando Imagen - 5 en ArroboMercy
# Procesando Imagen - 6 en ArroboMercy
# Procesando Imagen - 7 en ArroboMercy
# Procesando Imagen - 8 en ArroboMercy
# Procesando Imagen - 9 en ArroboMercy
# Procesando Imagen - 10 en ArroboMercy
# Procesando Imagen - 11 en ArroboMercy
# Procesando Imagen - 12 en ArroboMercy
# Procesando Imagen - 13 en ArroboMercy
# Procesando Imagen - 14 en ArroboMercy
# Procesando Imagen - 15 en ArroboMercy
# Procesando Imagen - 16 en ArroboMercy
# Procesando Imagen - 17 en ArroboMercy
# Procesando Imagen - 18 en ArroboMercy
# Procesando Imagen - 19 en ArroboMercy
# Procesando Imagen - 20 en ArroboMercy
# Procesando Imagen - 21 en ArroboMercy
# Procesando Imagen - 22 en ArroboMercy
# Procesando Imagen - 23 en ArroboMercy
# Procesando Imagen - 24 en ArroboMercy
# Procesando Imagen - 25 en ArroboMercy
# Procesando Imagen - 26 en ArroboMercy
# Procesando Imagen - 27 en ArroboMercy
# Procesando Imagen - 28 en ArroboMercy
# Procesando Imagen - 29 en ArroboMercy
# Procesando Imagen - 30 en ArroboMercy
# Procesando Imagen - 1 en CevallosJoan
# Procesando Imagen - 2 en CevallosJoan
# Procesando Imagen - 3 en CevallosJoan
# Procesando Imagen - 4 en CevallosJoan
# Procesando Imagen - 5 en CevallosJoan
# Procesando Imagen - 6 en CevallosJoan
# Procesando Imagen - 7 en CevallosJoan
# Procesando Imagen - 8 en CevallosJoan
# Procesando Imagen - 9 en CevallosJoan
# Procesando Imagen - 10 en CevallosJoan
# Procesando Imagen - 11 en CevallosJoan
# Procesando Imagen - 12 en CevallosJoan
# Procesando Imagen - 13 en CevallosJoan
# Procesando Imagen - 14 en CevallosJoan
# Procesando Imagen - 15 en CevallosJoan
# Procesando Imagen - 16 en CevallosJoan
# Procesando Imagen - 17 en CevallosJoan
# Procesando Imagen - 18 en CevallosJoan
# Procesando Imagen - 19 en CevallosJoan
# Procesando Imagen - 20 en CevallosJoan
# Procesando Imagen - 21 en CevallosJoan
# Procesando Imagen - 22 en CevallosJoan
# Procesando Imagen - 23 en CevallosJoan
# Procesando Imagen - 24 en CevallosJoan
# Procesando Imagen - 25 en CevallosJoan
# Procesando Imagen - 26 en CevallosJoan
# Procesando Imagen - 27 en CevallosJoan
# Procesando Imagen - 28 en CevallosJoan
# Procesando Imagen - 29 en CevallosJoan
# Procesando Imagen - 30 en CevallosJoan
# Procesando Imagen - 1 en GenesisHeredia
# Procesando Imagen - 2 en GenesisHeredia
# Procesando Imagen - 3 en GenesisHeredia
# Procesando Imagen - 4 en GenesisHeredia
# Procesando Imagen - 5 en GenesisHeredia
# Procesando Imagen - 6 en GenesisHeredia
# Procesando Imagen - 7 en GenesisHeredia
# Procesando Imagen - 8 en GenesisHeredia
# Procesando Imagen - 9 en GenesisHeredia
# Procesando Imagen - 10 en GenesisHeredia
# Procesando Imagen - 11 en GenesisHeredia
# Procesando Imagen - 12 en GenesisHeredia
# Procesando Imagen - 13 en GenesisHeredia
# Procesando Imagen - 14 en GenesisHeredia
# Procesando Imagen - 15 en GenesisHeredia
# Procesando Imagen - 16 en GenesisHeredia
# Procesando Imagen - 17 en GenesisHeredia
# Procesando Imagen - 18 en GenesisHeredia
# Procesando Imagen - 19 en GenesisHeredia
# Procesando Imagen - 20 en GenesisHeredia
# Procesando Imagen - 21 en GenesisHeredia
# Procesando Imagen - 22 en GenesisHeredia
# Procesando Imagen - 23 en GenesisHeredia
# Procesando Imagen - 24 en GenesisHeredia
# Procesando Imagen - 25 en GenesisHeredia
# Procesando Imagen - 26 en GenesisHeredia
# Procesando Imagen - 27 en GenesisHeredia
# Procesando Imagen - 28 en GenesisHeredia
# Procesando Imagen - 29 en GenesisHeredia
# Procesando Imagen - 30 en GenesisHeredia
# Procesando Imagen - 1 en PauteKevin
# Procesando Imagen - 2 en PauteKevin
# Procesando Imagen - 3 en PauteKevin
# Procesando Imagen - 4 en PauteKevin
# Procesando Imagen - 5 en PauteKevin
# Procesando Imagen - 6 en PauteKevin
# Procesando Imagen - 7 en PauteKevin
# Procesando Imagen - 8 en PauteKevin
# Procesando Imagen - 9 en PauteKevin
# Procesando Imagen - 10 en PauteKevin
# Procesando Imagen - 11 en PauteKevin
# Procesando Imagen - 12 en PauteKevin
# Procesando Imagen - 13 en PauteKevin
# Procesando Imagen - 14 en PauteKevin
# Procesando Imagen - 15 en PauteKevin
# Procesando Imagen - 16 en PauteKevin
# Procesando Imagen - 17 en PauteKevin
# Procesando Imagen - 18 en PauteKevin
# Procesando Imagen - 19 en PauteKevin
# Procesando Imagen - 20 en PauteKevin
# Procesando Imagen - 21 en PauteKevin
# Procesando Imagen - 22 en PauteKevin
# Procesando Imagen - 23 en PauteKevin
# Procesando Imagen - 24 en PauteKevin
# Procesando Imagen - 25 en PauteKevin
# Procesando Imagen - 26 en PauteKevin
# Procesando Imagen - 27 en PauteKevin
# Procesando Imagen - 28 en PauteKevin
# Procesando Imagen - 29 en PauteKevin
# Procesando Imagen - 30 en PauteKevin
# Procesando Imagen - 1 en RivasSelena
# Procesando Imagen - 2 en RivasSelena
# Procesando Imagen - 3 en RivasSelena
# Procesando Imagen - 4 en RivasSelena
# Procesando Imagen - 5 en RivasSelena
# Procesando Imagen - 6 en RivasSelena
# Procesando Imagen - 7 en RivasSelena
# Procesando Imagen - 8 en RivasSelena
# Procesando Imagen - 9 en RivasSelena
# Procesando Imagen - 10 en RivasSelena
# Procesando Imagen - 11 en RivasSelena
# Procesando Imagen - 12 en RivasSelena
# Procesando Imagen - 13 en RivasSelena
# Procesando Imagen - 14 en RivasSelena
# Procesando Imagen - 15 en RivasSelena
# Procesando Imagen - 16 en RivasSelena
# Procesando Imagen - 17 en RivasSelena
# Procesando Imagen - 18 en RivasSelena
# Procesando Imagen - 19 en RivasSelena
# Procesando Imagen - 20 en RivasSelena
# Procesando Imagen - 21 en RivasSelena
# Procesando Imagen - 22 en RivasSelena
# Procesando Imagen - 23 en RivasSelena
# Procesando Imagen - 24 en RivasSelena
# Procesando Imagen - 25 en RivasSelena
# Procesando Imagen - 26 en RivasSelena
# Procesando Imagen - 27 en RivasSelena
# Procesando Imagen - 28 en RivasSelena
# Procesando Imagen - 29 en RivasSelena
# Procesando Imagen - 30 en RivasSelena
